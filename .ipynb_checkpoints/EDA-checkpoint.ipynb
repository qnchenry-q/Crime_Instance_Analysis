# %%
#import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load data
raw_data = pd.read_csv('austin_crime.csv')
raw_data.name = 'Raw Data'
#view data
raw_data
# Out:
#                                      address census_tract  \
# 0         2620 RIO GRANDE ST Austin TX 78705         6.03
# 1       9500 S IH 35 SVRD SB Austin TX 78748        24.21
# 2                             1000 E 41ST ST          NaN
# 3                            Austin TX 78751          NaN
# 4                     (30.298356 -97.719647)         3.02
# ...                                      ...          ...
# 159459                (30.207396 -97.728709)        24.31
# 159460   10713 JOLLYVILLE RD Austin TX 78759        17.22
# 159461                  1712 TIMBER RIDGE DR          NaN
# 159462                       Austin TX 78741          NaN
# 159463                (30.226552 -97.741977)        23.07
#
#              clearance_date   clearance_status  council_district_code  \
# 0       2015-12-14 00:00:00        Not cleared                    9.0
# 1       2015-09-14 00:00:00  Cleared by Arrest                    5.0
# 2                       NaN                NaN                    NaN
# 3                       NaN                NaN                    NaN
# 4       2014-07-29 00:00:00  Cleared by Arrest                    9.0
# ...                     ...                ...                    ...
# 159459  2014-06-04 00:00:00        Not cleared                    2.0
# 159460  2016-01-12 00:00:00        Not cleared                   10.0
# 159461                  NaN                NaN                    NaN
# 159462                  NaN                NaN                    NaN
# 159463  2014-07-30 00:00:00        Not cleared                    3.0
#
#                  description district   latitude               location  \
# 0                      THEFT        B        NaN                    NaN
# 1       THEFT BY SHOPLIFTING        F        NaN                    NaN
# 2                        NaN      NaN        NaN                    NaN
# 3                        NaN      NaN        NaN                    NaN
# 4       THEFT BY SHOPLIFTING        B  30.298356  (30.298356-97.719647)
# ...                      ...      ...        ...                    ...
# 159459        THEFT OF METAL        F  30.207396  (30.207396-97.728709)
# 159460  THEFT BY SHOPLIFTING        A        NaN                    NaN
# 159461                   NaN      NaN        NaN                    NaN
# 159462                   NaN      NaN        NaN                    NaN
# 159463                 THEFT        H  30.226552  (30.226552-97.741977)
#
#         location_description  longitude              primary_type  \
# 0         2620 RIO GRANDE ST        NaN                     Theft
# 1       9500 S IH 35 SVRD SB        NaN                     Theft
# 2                        NaN        NaN                       NaN
# 3                        NaN        NaN                       NaN
# 4             1000 E 41ST ST -97.719647        Theft: Shoplifting
# ...                      ...        ...                       ...
# 159459         4000 CAVEN RD -97.728709  Theft: All Other Larceny
# 159460   10713 JOLLYVILLE RD        NaN                     Theft
# 159461                   NaN        NaN                       NaN
# 159462                   NaN        NaN                       NaN
# 159463  1712 TIMBER RIDGE DR -97.741977  Theft: All Other Larceny
#
#                   timestamp    unique_key  x_coordinate  y_coordinate    year  \
# 0       2015-12-13 00:00:00  2.015505e+10     3113531.0    10079579.0  2015.0
# 1       2015-09-03 00:00:00  2.015246e+10     3099459.0    10032098.0  2015.0
# 2                       NaN           NaN           NaN           NaN     NaN
# 3                       NaN           NaN           NaN           NaN     NaN
# 4       2014-04-04 00:00:00  2.014941e+09     3121345.0    10082705.0  2014.0
# ...                     ...           ...           ...           ...     ...
# 159459  2014-06-03 00:00:00  2.014502e+10     3119195.0    10048844.0  2014.0
# 159460  2015-12-30 00:00:00  2.015506e+10     3111397.0    10118845.0  2015.0
# 159461                  NaN           NaN           NaN           NaN     NaN
# 159462                  NaN           NaN           NaN           NaN     NaN
# 159463  2014-06-30 00:00:00  2.014503e+10     3114890.0    10055706.0  2014.0
#
#         zipcode
# 0       78705.0
# 1       78748.0
# 2           NaN
# 3           NaN
# 4       78751.0
# ...         ...
# 159459  78744.0
# 159460  78759.0
# 159461      NaN
# 159462      NaN
# 159463  78741.0
#
# [159464 rows x 18 columns]

# %%
#check out data if all rows with NaN's are dropped
drop_nans = raw_data.copy().dropna()

drop_nans
# Out:
#                        address        census_tract       clearance_date  \
# 4       (30.298356 -97.719647)                3.02  2014-07-29 00:00:00
# 9       (30.272154 -97.730002)   8.029999999999999  2014-05-08 00:00:00
# 14      (30.201243 -97.709249)               24.31  2014-05-09 00:00:00
# 17      (30.271198 -97.705609)                8.02  2014-12-19 00:00:00
# 20      (30.356418 -97.731423)  18.170000000000002  2014-04-17 00:00:00
# ...                        ...                 ...                  ...
# 159450  (30.312239 -97.662693)               22.01  2014-12-05 00:00:00
# 159453  (30.393536 -97.645133)               18.39  2014-03-27 00:00:00
# 159456   (30.405797 -97.74491)               17.54  2015-01-04 00:00:00
# 159459  (30.207396 -97.728709)               24.31  2014-06-04 00:00:00
# 159463  (30.226552 -97.741977)               23.07  2014-07-30 00:00:00
#
#          clearance_status  council_district_code  \
# 4       Cleared by Arrest                    9.0
# 9             Not cleared                    1.0
# 14            Not cleared                    2.0
# 17            Not cleared                    1.0
# 20            Not cleared                    7.0
# ...                   ...                    ...
# 159450        Not cleared                    1.0
# 159453        Not cleared                    7.0
# 159456        Not cleared                    7.0
# 159459        Not cleared                    2.0
# 159463        Not cleared                    3.0
#
#                            description district   latitude  \
# 4                 THEFT BY SHOPLIFTING        B  30.298356
# 9                           AUTO THEFT        C  30.272154
# 14                               THEFT        H  30.201243
# 17                          AUTO THEFT        C  30.271198
# 20                               THEFT        B  30.356418
# ...                                ...      ...        ...
# 159450                           THEFT        C  30.312239
# 159453                           THEFT        E  30.393536
# 159456  AGG ASLT ENHANC STRANGL/SUFFOC        A  30.405797
# 159459                  THEFT OF METAL        F  30.207396
# 159463                           THEFT        H  30.226552
#
#                      location         location_description  longitude  \
# 4       (30.298356-97.719647)               1000 E 41ST ST -97.719647
# 9       (30.272154-97.730002)               1000 E 12TH ST -97.730002
# 14      (30.201243-97.709249)             6800 BURLESON RD -97.709249
# 17      (30.271198-97.705609)          3506 WEBBERVILLE RD -97.705609
# 20      (30.356418-97.731423)           2438 W ANDERSON LN -97.731423
# ...                       ...                          ...        ...
# 159450  (30.312239-97.662693)    7112 ED BLUESTEIN BLVD NB -97.662693
# 159453  (30.393536-97.645133)              12600 DESSAU RD -97.645133
# 159456   (30.405797-97.74491)  11111 RESEARCH BLVD SVRD NB -97.744910
# 159459  (30.207396-97.728709)                4000 CAVEN RD -97.728709
# 159463  (30.226552-97.741977)         1712 TIMBER RIDGE DR -97.741977
#
#                     primary_type            timestamp    unique_key  \
# 4             Theft: Shoplifting  2014-04-04 00:00:00  2.014941e+09
# 9                     Auto Theft  2014-04-04 00:00:00  2.014941e+09
# 14      Theft: All Other Larceny  2014-05-08 00:00:00  2.014502e+10
# 17                    Auto Theft  2014-12-18 00:00:00  2.014352e+10
# 20      Theft: All Other Larceny  2014-04-16 00:00:00  2.014502e+10
# ...                          ...                  ...           ...
# 159450  Theft: All Other Larceny  2014-11-25 00:00:00  2.014505e+10
# 159453  Theft: All Other Larceny  2014-03-26 00:00:00  2.014851e+09
# 159456        Aggravated Assault  2014-12-28 00:00:00  2.014362e+10
# 159459  Theft: All Other Larceny  2014-06-03 00:00:00  2.014502e+10
# 159463  Theft: All Other Larceny  2014-06-30 00:00:00  2.014503e+10
#
#         x_coordinate  y_coordinate    year  zipcode
# 4          3121345.0    10082705.0  2014.0  78751.0
# 9          3118304.0    10072414.0  2014.0  78702.0
# 14         3125886.0    10047276.0  2014.0  78744.0
# 17         3125976.0    10072207.0  2014.0  78702.0
# 20         3117183.0    10103211.0  2014.0  78757.0
# ...              ...           ...     ...      ...
# 159450     3139137.0    10088360.0  2014.0  78724.0
# 159453     3144046.0    10117185.0  2014.0  78753.0
# 159456     3112507.0    10120833.0  2014.0  78759.0
# 159459     3119195.0    10048844.0  2014.0  78744.0
# 159463     3114890.0    10055706.0  2014.0  78741.0
#
# [27459 rows x 18 columns]

# %%
#BE SURE TO MENTION HOW THE DATA IS SUBSETTED IN PRESENTATION/README
#the above data is sufficient, rename dataframe, delete temp, show renamed df
no_nulls_df = drop_nans
no_nulls_df.name = 'Dropped Nulls DataFrame'
#del drop_nans
no_nulls_df
# Out:
#                        address        census_tract       clearance_date  \
# 4       (30.298356 -97.719647)                3.02  2014-07-29 00:00:00
# 9       (30.272154 -97.730002)   8.029999999999999  2014-05-08 00:00:00
# 14      (30.201243 -97.709249)               24.31  2014-05-09 00:00:00
# 17      (30.271198 -97.705609)                8.02  2014-12-19 00:00:00
# 20      (30.356418 -97.731423)  18.170000000000002  2014-04-17 00:00:00
# ...                        ...                 ...                  ...
# 159450  (30.312239 -97.662693)               22.01  2014-12-05 00:00:00
# 159453  (30.393536 -97.645133)               18.39  2014-03-27 00:00:00
# 159456   (30.405797 -97.74491)               17.54  2015-01-04 00:00:00
# 159459  (30.207396 -97.728709)               24.31  2014-06-04 00:00:00
# 159463  (30.226552 -97.741977)               23.07  2014-07-30 00:00:00
#
#          clearance_status  council_district_code  \
# 4       Cleared by Arrest                    9.0
# 9             Not cleared                    1.0
# 14            Not cleared                    2.0
# 17            Not cleared                    1.0
# 20            Not cleared                    7.0
# ...                   ...                    ...
# 159450        Not cleared                    1.0
# 159453        Not cleared                    7.0
# 159456        Not cleared                    7.0
# 159459        Not cleared                    2.0
# 159463        Not cleared                    3.0
#
#                            description district   latitude  \
# 4                 THEFT BY SHOPLIFTING        B  30.298356
# 9                           AUTO THEFT        C  30.272154
# 14                               THEFT        H  30.201243
# 17                          AUTO THEFT        C  30.271198
# 20                               THEFT        B  30.356418
# ...                                ...      ...        ...
# 159450                           THEFT        C  30.312239
# 159453                           THEFT        E  30.393536
# 159456  AGG ASLT ENHANC STRANGL/SUFFOC        A  30.405797
# 159459                  THEFT OF METAL        F  30.207396
# 159463                           THEFT        H  30.226552
#
#                      location         location_description  longitude  \
# 4       (30.298356-97.719647)               1000 E 41ST ST -97.719647
# 9       (30.272154-97.730002)               1000 E 12TH ST -97.730002
# 14      (30.201243-97.709249)             6800 BURLESON RD -97.709249
# 17      (30.271198-97.705609)          3506 WEBBERVILLE RD -97.705609
# 20      (30.356418-97.731423)           2438 W ANDERSON LN -97.731423
# ...                       ...                          ...        ...
# 159450  (30.312239-97.662693)    7112 ED BLUESTEIN BLVD NB -97.662693
# 159453  (30.393536-97.645133)              12600 DESSAU RD -97.645133
# 159456   (30.405797-97.74491)  11111 RESEARCH BLVD SVRD NB -97.744910
# 159459  (30.207396-97.728709)                4000 CAVEN RD -97.728709
# 159463  (30.226552-97.741977)         1712 TIMBER RIDGE DR -97.741977
#
#                     primary_type            timestamp    unique_key  \
# 4             Theft: Shoplifting  2014-04-04 00:00:00  2.014941e+09
# 9                     Auto Theft  2014-04-04 00:00:00  2.014941e+09
# 14      Theft: All Other Larceny  2014-05-08 00:00:00  2.014502e+10
# 17                    Auto Theft  2014-12-18 00:00:00  2.014352e+10
# 20      Theft: All Other Larceny  2014-04-16 00:00:00  2.014502e+10
# ...                          ...                  ...           ...
# 159450  Theft: All Other Larceny  2014-11-25 00:00:00  2.014505e+10
# 159453  Theft: All Other Larceny  2014-03-26 00:00:00  2.014851e+09
# 159456        Aggravated Assault  2014-12-28 00:00:00  2.014362e+10
# 159459  Theft: All Other Larceny  2014-06-03 00:00:00  2.014502e+10
# 159463  Theft: All Other Larceny  2014-06-30 00:00:00  2.014503e+10
#
#         x_coordinate  y_coordinate    year  zipcode
# 4          3121345.0    10082705.0  2014.0  78751.0
# 9          3118304.0    10072414.0  2014.0  78702.0
# 14         3125886.0    10047276.0  2014.0  78744.0
# 17         3125976.0    10072207.0  2014.0  78702.0
# 20         3117183.0    10103211.0  2014.0  78757.0
# ...              ...           ...     ...      ...
# 159450     3139137.0    10088360.0  2014.0  78724.0
# 159453     3144046.0    10117185.0  2014.0  78753.0
# 159456     3112507.0    10120833.0  2014.0  78759.0
# 159459     3119195.0    10048844.0  2014.0  78744.0
# 159463     3114890.0    10055706.0  2014.0  78741.0
#
# [27459 rows x 18 columns]

# %%
#create categorical value_counts dictionary
def value_counts_dict_on_frame(df, columns):
    res = {}           # dictionary with column name as key, value_counts Series as key
    for c in columns:
        res[c] = df[c].value_counts(dropna = False)
    return res

# %%
#store a dictionary for categorical values [no_nulls_df] in variable
categorical_columns = ['clearance_status', 'council_district_code', 
                    'district', 'primary_type', 'year', 'zipcode']
categorical_vc_dict_nulless_df = value_counts_dict_on_frame(no_nulls_df, categorical_columns)

# %%
#plot distributions of certain columns function
def plot_distributions(df, columns):
    fig, axs = plt.subplots(len(columns), figsize = (10, 20))
    for i,column in zip(axs.flatten(), columns):
        array = df[column]
        array.hist(ax = i)
        i.set_title(f'{column} distribution in {df.name}')
        i.set_xlabel(f'{column} value')
        i.set_ylabel(f'# of occurences in {df.name}')
    fig.tight_layout()

# %%
#plot distributions on raw data
plot_distributions(raw_data, categorical_columns)

# %%
#examine dictionary of the above distributions in raw_data
#noted that there are many labels with sparse entires, considering 'Other' category on several fields
raw_vc_dictionary_categorical = value_counts_dict_on_frame (raw_data, categorical_columns)
for entry in raw_vc_dictionary_categorical.values():
    print(entry)
    print()
    print()
# Out:
# NaN                     77984
# Not cleared             62471
# Cleared by Arrest       11275
# Cleared by Exception     2073
# 3122189                    35
#                         ...
# 3128140                     1
# 3130412                     1
# 3136232                     1
# 3134008                     1
# 3100666                     1
# Name: clearance_status, Length: 4073, dtype: int64
#
#
# NaN           75008
# 3.0           12176
# 9.0           11767
# 4.0           11412
# 7.0            9190
#               ...
# 10046614.0        1
# 10108606.0        1
# 10030238.0        1
# 10063121.0        1
# 10115882.0        1
# Name: council_district_code, Length: 4170, dtype: int64
#
#
# NaN      74593
# D        11346
# E        10599
# F         9811
# B         9247
# I         8971
# A         8769
# H         8030
# C         6317
# G         5584
# 78741      598
# 78753      440
# 78745      435
# 78758      412
# 78744      407
# 78702      374
# 78723      330
# 78704      318
# AP         298
# UK         242
# 78748      203
# 78757      189
# 78752      162
# 78759      156
# 78721      146
# 78705      133
# 78724      127
# 78751      100
# 78754       94
# 78749       86
# 78731       83
# 78701       83
# 78727       78
# 78729       78
# 78756       76
# 78703       76
# 78750       72
# 78722       57
# 78747       56
# 78717       56
# 78735       50
# 78617       48
# 78746       36
# 78726       16
# 78660       16
# 78725       15
# 78739       13
# 78742       11
# 78736       10
# 78730        8
# 78613        3
# 78653        3
# 78728        2
# 78719        1
# Name: district, dtype: int64
#
#
# NaN                                             80250
# Theft                                           28274
# Theft: All Other Larceny                        13539
# Theft: BOV                                      10545
# Burglary /                                       5670
# Burglary                                         4927
# Theft: Shoplifting                               4284
# Auto Theft                                       4206
# Agg Assault                                      1915
# Aggravated Assault                               1888
# Robbery                                          1809
# Rape                                             1042
# Theft: Pocket Picking                             448
# Theft: Auto Parts                                 231
# Theft: from Building                              221
# Theft: Coin Op Machine                            153
# Homicide: Murder & Nonnegligent Manslaughter       32
# Murder                                             23
# Theft: Purse Snatching                              7
# Name: primary_type, dtype: int64
#
#
# NaN       85920
# 2015.0    38573
# 2014.0    34971
# Name: year, dtype: int64
#
#
# NaN        86263
# 78753.0     6967
# 78741.0     5769
# 78758.0     4977
# 78704.0     4968
# 78745.0     4564
# 78701.0     4056
# 78723.0     3877
# 78744.0     3709
# 78702.0     3490
# 78748.0     2883
# 78759.0     2804
# 78705.0     2351
# 78752.0     2337
# 78757.0     2095
# 78751.0     1753
# 78749.0     1577
# 78746.0     1566
# 78703.0     1322
# 78731.0     1010
# 78727.0      993
# 78721.0      975
# 78724.0      972
# 78729.0      884
# 78754.0      791
# 78613.0      791
# 78750.0      756
# 78756.0      631
# 78722.0      622
# 78735.0      528
# 78617.0      502
# 78747.0      468
# 78717.0      438
# 78726.0      425
# 78719.0      312
# 78739.0      305
# 78660.0      244
# 78736.0      118
# 78725.0      106
# 78730.0       90
# 78742.0       65
# 78653.0       45
# 78728.0       19
# 78652.0       16
# 78712.0       15
# 78737.0        6
# 78732.0        4
# 78733.0        3
# 78610.0        2
# Name: zipcode, dtype: int64

# %%
##### START HERE!!!!!!!!!!!!!!!! ######
#exmine series 1/6 in ['clearance_status', 'council_district_code', 'district', 'primary_type', 'year', 'zipcode']
raw_vc_dictionary_categorical['clearance_status']
# Out:
# NaN                     77984
# Not cleared             62471
# Cleared by Arrest       11275
# Cleared by Exception     2073
# 3122189                    35
#                         ...
# 3128140                     1
# 3130412                     1
# 3136232                     1
# 3134008                     1
# 3100666                     1
# Name: clearance_status, Length: 4073, dtype: int64

# %%
#Begin creating 'categorized df' here when cycling back to EDA ********************************
#above we saw that most of the series are top heavy, create 'other' categories for the sparse categories to reduce
#the number of categories and see a better plot of the data
categorized_df = raw_data.copy()

# %%
#create df with full long/lat
long_lat_df = pd.DataFrame(columns = categorized_df['latitude', 'longitude']).dropna()
long_lat_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5fe2d1a9de85> in <module>
#       1 #create df with full long/lat
# ----> 2 long_lat_df = pd.DataFrame(columns = categorized_df['latitude', 'longitude']).dropna()
#       3 long_lat_df
#
# NameError: name 'pd' is not defined
