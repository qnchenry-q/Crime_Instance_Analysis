# %%
from sklearn.tree import export_graphviz, DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.inspection import permutation_importance, plot_partial_dependence

from scipy.special import comb
from scipy import stats


import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('feature_df.csv')
df
# Out:
#        Unnamed: 0  census_tract  council_district_code district  \
# 0               0          6.03                    9.0        B
# 1               1         24.21                    5.0        F
# 2               4          3.02                    9.0        B
# 3               5         24.03                    3.0        D
# 4               6         24.13                    2.0        F
# ...           ...           ...                    ...      ...
# 78228      159453         18.39                    7.0        E
# 78229      159456         17.54                    7.0        A
# 78230      159459         24.31                    2.0        F
# 78231      159460         17.22                   10.0        A
# 78232      159463         23.07                    3.0        H
#
#                    primary_type    unique_key  zipcode  severe  \
# 0                         Theft  2.015505e+10  78705.0   False
# 1                         Theft  2.015246e+10  78748.0   False
# 2            Theft: Shoplifting  2.014941e+09  78751.0   False
# 3                         Theft  2.015209e+08  78745.0   False
# 4                         Theft  2.015209e+10  78744.0   False
# ...                         ...           ...      ...     ...
# 78228  Theft: All Other Larceny  2.014851e+09  78753.0   False
# 78229        Aggravated Assault  2.014362e+10  78759.0    True
# 78230  Theft: All Other Larceny  2.014502e+10  78744.0   False
# 78231                     Theft  2.015506e+10  78759.0   False
# 78232  Theft: All Other Larceny  2.014503e+10  78741.0   False
#
#                          point North_South  month   day   day_name  season  \
# 0                   (nan, nan)       South   12.0  13.0     Sunday     4.0
# 1                   (nan, nan)       South    9.0   3.0   Thursday     3.0
# 2      (30.298356, -97.719647)       North    4.0   4.0     Friday     2.0
# 3                   (nan, nan)       South    1.0   2.0     Friday     1.0
# 4                   (nan, nan)       South    7.0  28.0    Tuesday     3.0
# ...                        ...         ...    ...   ...        ...     ...
# 78228  (30.393536, -97.645133)       North    3.0  26.0  Wednesday     1.0
# 78229   (30.405797, -97.74491)       North   12.0  28.0     Sunday     4.0
# 78230  (30.207396, -97.728709)       South    6.0   3.0    Tuesday     2.0
# 78231               (nan, nan)       North   12.0  30.0  Wednesday     4.0
# 78232  (30.226552, -97.741977)       South    6.0  30.0     Monday     2.0
#
#        cluster
# 0          4.0
# 1          5.0
# 2          4.0
# 3          3.0
# 4          5.0
# ...        ...
# 78228      2.0
# 78229      8.0
# 78230      7.0
# 78231      8.0
# 78232      7.0
#
# [78233 rows x 15 columns]

# %%
pre_feature_df = df.drop(['unique_key', 'census_tract'], axis = 1)
pre_feature_df = pre_feature_df.rename(columns = {'Unnamed: 0': 'original_idx'}) 
pre_feature_df
# Out:
#        original_idx  council_district_code district              primary_type  \
# 0                 0                    9.0        B                     Theft
# 1                 1                    5.0        F                     Theft
# 2                 4                    9.0        B        Theft: Shoplifting
# 3                 5                    3.0        D                     Theft
# 4                 6                    2.0        F                     Theft
# ...             ...                    ...      ...                       ...
# 78228        159453                    7.0        E  Theft: All Other Larceny
# 78229        159456                    7.0        A        Aggravated Assault
# 78230        159459                    2.0        F  Theft: All Other Larceny
# 78231        159460                   10.0        A                     Theft
# 78232        159463                    3.0        H  Theft: All Other Larceny
#
#        zipcode  severe                    point North_South  month   day  \
# 0      78705.0   False               (nan, nan)       South   12.0  13.0
# 1      78748.0   False               (nan, nan)       South    9.0   3.0
# 2      78751.0   False  (30.298356, -97.719647)       North    4.0   4.0
# 3      78745.0   False               (nan, nan)       South    1.0   2.0
# 4      78744.0   False               (nan, nan)       South    7.0  28.0
# ...        ...     ...                      ...         ...    ...   ...
# 78228  78753.0   False  (30.393536, -97.645133)       North    3.0  26.0
# 78229  78759.0    True   (30.405797, -97.74491)       North   12.0  28.0
# 78230  78744.0   False  (30.207396, -97.728709)       South    6.0   3.0
# 78231  78759.0   False               (nan, nan)       North   12.0  30.0
# 78232  78741.0   False  (30.226552, -97.741977)       South    6.0  30.0
#
#         day_name  season  cluster
# 0         Sunday     4.0      4.0
# 1       Thursday     3.0      5.0
# 2         Friday     2.0      4.0
# 3         Friday     1.0      3.0
# 4        Tuesday     3.0      5.0
# ...          ...     ...      ...
# 78228  Wednesday     1.0      2.0
# 78229     Sunday     4.0      8.0
# 78230    Tuesday     2.0      7.0
# 78231  Wednesday     4.0      8.0
# 78232     Monday     2.0      7.0
#
# [78233 rows x 13 columns]

# %%
feature_df = pre_feature_df.copy()
feature_df = feature_df.drop(['original_idx'], axis = 1 )
feature_df
# Out:
#        council_district_code district              primary_type  zipcode  \
# 0                        9.0        B                     Theft  78705.0
# 1                        5.0        F                     Theft  78748.0
# 2                        9.0        B        Theft: Shoplifting  78751.0
# 3                        3.0        D                     Theft  78745.0
# 4                        2.0        F                     Theft  78744.0
# ...                      ...      ...                       ...      ...
# 78228                    7.0        E  Theft: All Other Larceny  78753.0
# 78229                    7.0        A        Aggravated Assault  78759.0
# 78230                    2.0        F  Theft: All Other Larceny  78744.0
# 78231                   10.0        A                     Theft  78759.0
# 78232                    3.0        H  Theft: All Other Larceny  78741.0
#
#        severe                    point North_South  month   day   day_name  \
# 0       False               (nan, nan)       South   12.0  13.0     Sunday
# 1       False               (nan, nan)       South    9.0   3.0   Thursday
# 2       False  (30.298356, -97.719647)       North    4.0   4.0     Friday
# 3       False               (nan, nan)       South    1.0   2.0     Friday
# 4       False               (nan, nan)       South    7.0  28.0    Tuesday
# ...       ...                      ...         ...    ...   ...        ...
# 78228   False  (30.393536, -97.645133)       North    3.0  26.0  Wednesday
# 78229    True   (30.405797, -97.74491)       North   12.0  28.0     Sunday
# 78230   False  (30.207396, -97.728709)       South    6.0   3.0    Tuesday
# 78231   False               (nan, nan)       North   12.0  30.0  Wednesday
# 78232   False  (30.226552, -97.741977)       South    6.0  30.0     Monday
#
#        season  cluster
# 0         4.0      4.0
# 1         3.0      5.0
# 2         2.0      4.0
# 3         1.0      3.0
# 4         3.0      5.0
# ...       ...      ...
# 78228     1.0      2.0
# 78229     4.0      8.0
# 78230     2.0      7.0
# 78231     4.0      8.0
# 78232     2.0      7.0
#
# [78233 rows x 12 columns]

# %%
#Set up train test split with One HOt encoding
one_hot = OneHotEncoder()
y0 = feature_df.severe

X0 = one_hot.fit_transform(feature_df.copy().drop('severe',axis = 1))
X0_train, X0_test, y0_train, y0_test = train_test_split(X0, y0, 
                                                    test_size=.2)

# %%
# Train and fit model                                                   
rf0 = RandomForestClassifier(random_state=0,n_jobs=-1)

rf0.fit(X0_train, y0_train)
                                     
# Test Prediction
pred = rf0.predict(X0_test)
print('Accuracy score: {:.3}'.format(rf0.score(X0_test, y0_test)))
# Out:
# Accuracy score: 0.998

# %%
### Try taking out primary_type since severe is derived from it
y1 = feature_df.severe
X1 = one_hot.fit_transform(feature_df.copy().drop(['severe', 'primary_type'],axis = 1))

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=.2)

# %%
# Train and fit model                                                   
rf1 = RandomForestClassifier(random_state=0,n_jobs=-1)

rf1.fit(X1_train, y1_train)
                                     
# Test Prediction
pred = rf1.predict(X1_test)
print('Accuracy score: {:.3}'.format(rf1.score(X1_test, y1_test)))
# Out:
# Accuracy score: 0.793

# %%
feature_df.severe.value_counts()
# Out:
# False    57572
# True     20661
# Name: severe, dtype: int64

# %%
# Confusion Matrix, Gini plot
# Group Data, predict by group

feature_df1 = feature_df.copy().drop(['severe', 'primary_type'], axis = 1)
one_hot_columns = one_hot.get_feature_names(feature_df1.columns)
# Plot the feature importance
feat_scores1 = pd.Series(rf1.feature_importances_, index = one_hot_columns )
feat_scores1 = feat_scores1.sort_values()
ax = feat_scores1[-11:].plot(kind='barh', 
                      figsize=(10,8),
                      color='b')
ax.set_title('Average Gini Importance')
ax.set_xlabel('Average contribution to information gain');

# %%
feat_scores1.tail()
# Out:
# season_nan     0.031466
# zipcode_nan    0.038772
# month_nan      0.039617
# day_nan        0.039872
# cluster_nan    0.040225
# dtype: float64

# %%
no_nans = feature_df.copy().dropna()

# %%
#Set up train test split with One HOt encoding
one_hot2 = OneHotEncoder()
y2 = no_nans.severe

X2 = one_hot.fit_transform(no_nans.copy().drop(['severe', 'primary_type'],axis = 1))
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, 
                                                    test_size=.2)

# %%
# Train and fit model                                                   
rf2 = RandomForestClassifier(random_state=0,n_jobs=-1)

rf2.fit(X2_train, y2_train)
                                     
# Test Prediction
pred = rf2.predict(X2_test)
print('Accuracy score: {:.3}'.format(rf2.score(X2_test, y2_test)))
# Out:
# Accuracy score: 0.774

# %%
#look into f1 for eval metric, know range of data(timewise)
# find out why missing dates are present 
# effect of nans on prediction [positive or negative] 
# plot distributions of target by group

# %%
target_df = pd.read_csv('Nulless_Target.csv')

# %%
target_df
# Out:
#        Unnamed: 0  census_tract  council_district_code district  \
# 0               0          6.03                    9.0        B
# 1               1         24.21                    5.0        F
# 2               4          3.02                    9.0        B
# 3               5         24.03                    3.0        D
# 4               6         24.13                    2.0        F
# ...           ...           ...                    ...      ...
# 79209      159453         18.39                    7.0        E
# 79210      159456         17.54                    7.0        A
# 79211      159459         24.31                    2.0        F
# 79212      159460         17.22                   10.0        A
# 79213      159463         23.07                    3.0        H
#
#                    primary_type    unique_key  zipcode  severe  \
# 0                         Theft  2.015505e+10  78705.0   False
# 1                         Theft  2.015246e+10  78748.0   False
# 2            Theft: Shoplifting  2.014941e+09  78751.0   False
# 3                         Theft  2.015209e+08  78745.0   False
# 4                         Theft  2.015209e+10  78744.0   False
# ...                         ...           ...      ...     ...
# 79209  Theft: All Other Larceny  2.014851e+09  78753.0   False
# 79210        Aggravated Assault  2.014362e+10  78759.0    True
# 79211  Theft: All Other Larceny  2.014502e+10  78744.0   False
# 79212                     Theft  2.015506e+10  78759.0   False
# 79213  Theft: All Other Larceny  2.014503e+10  78741.0   False
#
#                          point North_South  month   day   day_name  season  \
# 0                   (nan, nan)       South   12.0  13.0     Sunday     4.0
# 1                   (nan, nan)       South    9.0   3.0   Thursday     3.0
# 2      (30.298356, -97.719647)       North    4.0   4.0     Friday     2.0
# 3                   (nan, nan)       South    1.0   2.0     Friday     1.0
# 4                   (nan, nan)       South    7.0  28.0    Tuesday     3.0
# ...                        ...         ...    ...   ...        ...     ...
# 79209  (30.393536, -97.645133)       North    3.0  26.0  Wednesday     1.0
# 79210   (30.405797, -97.74491)       North   12.0  28.0     Sunday     4.0
# 79211  (30.207396, -97.728709)       South    6.0   3.0    Tuesday     2.0
# 79212               (nan, nan)       North   12.0  30.0  Wednesday     4.0
# 79213  (30.226552, -97.741977)       South    6.0  30.0     Monday     2.0
#
#        cluster
# 0          4.0
# 1          5.0
# 2          4.0
# 3          3.0
# 4          5.0
# ...        ...
# 79209      2.0
# 79210      8.0
# 79211      7.0
# 79212      8.0
# 79213      7.0
#
# [79214 rows x 15 columns]

# %%
target_df_p = target_df[feature_df.columns.tolist()]
target_df_p = target_df_p.drop('point', axis = 1)

# %%
#Here we will actually include as many nans as possible as opposed to above

# %%
#Set up train test split with One HOt encoding
one_hot3 = OneHotEncoder()
y3 = target_df_p.severe

X3 = one_hot3.fit_transform(target_df_p.copy().drop(['severe', 'primary_type'],axis = 1))
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, 
                                                    test_size=.2)

# %%
# Train and fit model                                                   
rf3 = RandomForestClassifier(random_state=0,n_jobs=-1)

rf3.fit(X3_train, y3_train)
                                     
# Test Prediction
pred = rf3.predict(X3_test)
print('Accuracy score: {:.3}'.format(rf3.score(X3_test, y3_test)))
# Out:
# Accuracy score: 0.779

# %%
feature_df2 = target_df_p.copy().drop(['severe', 'primary_type'], axis = 1)
one_hot_columns3 = one_hot3.get_feature_names(feature_df2.columns)
# Plot the feature importance
feat_scores3 = pd.Series(rf3.feature_importances_, index = one_hot_columns3 )
feat_scores3 = feat_scores3.sort_values()
ax = feat_scores3[-15:].plot(kind='barh', 
                      figsize=(10,8),
                      color='b')
ax.set_title('Average Gini Importance')
ax.set_xlabel('Average contribution to information gain');

# %%
cluster_nan_df = target_df_p[target_df_p['cluster'].isna()]
zipcode_nan_df = target_df_p[target_df_p['zipcode'].isna()]
day_name_nan_df = target_df_p[target_df_p['day_name'].isna()]
month_nan_df = target_df_p[target_df_p['month'].isna()]
day_nan_df = target_df_p[target_df_p['day'].isna()]
season_nan_df = target_df_p[target_df_p['season'].isna()]

# %%
important_nans = [cluster_nan_df, zipcode_nan_df, day_name_nan_df,
                  month_nan_df, day_nan_df,season_nan_df]

# %%
names = ['clust_nan', 'zip_nan', 'day_name_nan', 'month_nan', 'day_nan','season_nan']
for df, name in zip(important_nans, names):
    df.name = name
    
for df in important_nans:
    print(df.name)
# Out:
# clust_nan
# zip_nan
# day_name_nan
# month_nan
# day_nan
# season_nan

# %%
fig, ax = plt.subplots(figsize = (15,15))
props_of_severe_in_nan = {}
for df in important_nans:
    prop = float(len(df[df['severe']==True])/ len(df))
    props_of_severe_in_nan[df.name] = prop
    

total_dist = float(len(target_df_p[target_df_p['severe']==True])/ len(target_df_p))
x_sigma = [x for x in props_of_severe_in_nan.keys()]
x_sigma.append('total data')
y_sigma = [x for x in props_of_severe_in_nan.values()]
y_sigma.append(total_dist)
ax.bar(x_sigma, y_sigma)
ax.set_title('Percentage of Severe crimes in Most Important Features')
print(y_sigma)
# Out:
# [0.9742112087595447, 0.9637452186928323, 0.9794433902593296, 0.9794433902593296, 0.9794433902593296, 0.9794433902593296, 0.2715681571439392]

# %%
cluster_nan_df
# Out:
#        council_district_code district primary_type  zipcode  severe  \
# 26                       2.0        F  Burglary /       NaN    True
# 31                       2.0        F  Burglary /       NaN    True
# 34                       8.0        D  Burglary /       NaN    True
# 38                       6.0        A  Burglary /       NaN    True
# 49                       1.0        I  Burglary /       NaN    True
# ...                      ...      ...          ...      ...     ...
# 79128                    7.0        E  Burglary /       NaN    True
# 79132                    2.0        F  Burglary /       NaN    True
# 79144                    4.0        E  Burglary /       NaN    True
# 79158                    1.0        C  Burglary /       NaN    True
# 79195                    1.0        I  Burglary /       NaN    True
#
#       North_South  month  day day_name  season  cluster
# 26            NaN    NaN  NaN      NaN     NaN      NaN
# 31          South    NaN  NaN      NaN     NaN      NaN
# 34          South    NaN  NaN      NaN     NaN      NaN
# 38          North    NaN  NaN      NaN     NaN      NaN
# 49          North    NaN  NaN      NaN     NaN      NaN
# ...           ...    ...  ...      ...     ...      ...
# 79128       North    NaN  NaN      NaN     NaN      NaN
# 79132       South    NaN  NaN      NaN     NaN      NaN
# 79144       North    NaN  NaN      NaN     NaN      NaN
# 79158       South    NaN  NaN      NaN     NaN      NaN
# 79195       North    NaN  NaN      NaN     NaN      NaN
#
# [6941 rows x 11 columns]

# %%
zipcode_nan_df
# Out:
#        council_district_code district primary_type  zipcode  severe  \
# 26                       2.0        F  Burglary /       NaN    True
# 31                       2.0        F  Burglary /       NaN    True
# 34                       8.0        D  Burglary /       NaN    True
# 38                       6.0        A  Burglary /       NaN    True
# 49                       1.0        I  Burglary /       NaN    True
# ...                      ...      ...          ...      ...     ...
# 79128                    7.0        E  Burglary /       NaN    True
# 79132                    2.0        F  Burglary /       NaN    True
# 79144                    4.0        E  Burglary /       NaN    True
# 79158                    1.0        C  Burglary /       NaN    True
# 79195                    1.0        I  Burglary /       NaN    True
#
#       North_South  month  day day_name  season  cluster
# 26            NaN    NaN  NaN      NaN     NaN      NaN
# 31          South    NaN  NaN      NaN     NaN      NaN
# 34          South    NaN  NaN      NaN     NaN      NaN
# 38          North    NaN  NaN      NaN     NaN      NaN
# 49          North    NaN  NaN      NaN     NaN      NaN
# ...           ...    ...  ...      ...     ...      ...
# 79128       North    NaN  NaN      NaN     NaN      NaN
# 79132       South    NaN  NaN      NaN     NaN      NaN
# 79144       North    NaN  NaN      NaN     NaN      NaN
# 79158       South    NaN  NaN      NaN     NaN      NaN
# 79195       North    NaN  NaN      NaN     NaN      NaN
#
# [6013 rows x 11 columns]

# %%
day_name_nan_df
# Out:
#        council_district_code district primary_type  zipcode  severe  \
# 26                       2.0        F  Burglary /       NaN    True
# 31                       2.0        F  Burglary /       NaN    True
# 34                       8.0        D  Burglary /       NaN    True
# 38                       6.0        A  Burglary /       NaN    True
# 49                       1.0        I  Burglary /       NaN    True
# ...                      ...      ...          ...      ...     ...
# 79128                    7.0        E  Burglary /       NaN    True
# 79132                    2.0        F  Burglary /       NaN    True
# 79144                    4.0        E  Burglary /       NaN    True
# 79158                    1.0        C  Burglary /       NaN    True
# 79195                    1.0        I  Burglary /       NaN    True
#
#       North_South  month  day day_name  season  cluster
# 26            NaN    NaN  NaN      NaN     NaN      NaN
# 31          South    NaN  NaN      NaN     NaN      NaN
# 34          South    NaN  NaN      NaN     NaN      NaN
# 38          North    NaN  NaN      NaN     NaN      NaN
# 49          North    NaN  NaN      NaN     NaN      NaN
# ...           ...    ...  ...      ...     ...      ...
# 79128       North    NaN  NaN      NaN     NaN      NaN
# 79132       South    NaN  NaN      NaN     NaN      NaN
# 79144       North    NaN  NaN      NaN     NaN      NaN
# 79158       South    NaN  NaN      NaN     NaN      NaN
# 79195       North    NaN  NaN      NaN     NaN      NaN
#
# [6324 rows x 11 columns]

# %%
day_nan_df
# Out:
#        council_district_code district primary_type  zipcode  severe  \
# 26                       2.0        F  Burglary /       NaN    True
# 31                       2.0        F  Burglary /       NaN    True
# 34                       8.0        D  Burglary /       NaN    True
# 38                       6.0        A  Burglary /       NaN    True
# 49                       1.0        I  Burglary /       NaN    True
# ...                      ...      ...          ...      ...     ...
# 79128                    7.0        E  Burglary /       NaN    True
# 79132                    2.0        F  Burglary /       NaN    True
# 79144                    4.0        E  Burglary /       NaN    True
# 79158                    1.0        C  Burglary /       NaN    True
# 79195                    1.0        I  Burglary /       NaN    True
#
#       North_South  month  day day_name  season  cluster
# 26            NaN    NaN  NaN      NaN     NaN      NaN
# 31          South    NaN  NaN      NaN     NaN      NaN
# 34          South    NaN  NaN      NaN     NaN      NaN
# 38          North    NaN  NaN      NaN     NaN      NaN
# 49          North    NaN  NaN      NaN     NaN      NaN
# ...           ...    ...  ...      ...     ...      ...
# 79128       North    NaN  NaN      NaN     NaN      NaN
# 79132       South    NaN  NaN      NaN     NaN      NaN
# 79144       North    NaN  NaN      NaN     NaN      NaN
# 79158       South    NaN  NaN      NaN     NaN      NaN
# 79195       North    NaN  NaN      NaN     NaN      NaN
#
# [6324 rows x 11 columns]

# %%
season_nan_df
# Out:
#        council_district_code district primary_type  zipcode  severe  \
# 26                       2.0        F  Burglary /       NaN    True
# 31                       2.0        F  Burglary /       NaN    True
# 34                       8.0        D  Burglary /       NaN    True
# 38                       6.0        A  Burglary /       NaN    True
# 49                       1.0        I  Burglary /       NaN    True
# ...                      ...      ...          ...      ...     ...
# 79128                    7.0        E  Burglary /       NaN    True
# 79132                    2.0        F  Burglary /       NaN    True
# 79144                    4.0        E  Burglary /       NaN    True
# 79158                    1.0        C  Burglary /       NaN    True
# 79195                    1.0        I  Burglary /       NaN    True
#
#       North_South  month  day day_name  season  cluster
# 26            NaN    NaN  NaN      NaN     NaN      NaN
# 31          South    NaN  NaN      NaN     NaN      NaN
# 34          South    NaN  NaN      NaN     NaN      NaN
# 38          North    NaN  NaN      NaN     NaN      NaN
# 49          North    NaN  NaN      NaN     NaN      NaN
# ...           ...    ...  ...      ...     ...      ...
# 79128       North    NaN  NaN      NaN     NaN      NaN
# 79132       South    NaN  NaN      NaN     NaN      NaN
# 79144       North    NaN  NaN      NaN     NaN      NaN
# 79158       South    NaN  NaN      NaN     NaN      NaN
# 79195       North    NaN  NaN      NaN     NaN      NaN
#
# [6324 rows x 11 columns]

# %%
target_df_p[target_df_p.primary_type == 'Burglary / '].zipcode.value_counts(dropna = False)
# Out:
# NaN    5670
# Name: zipcode, dtype: int64

# %%
target_df_p.primary_type.value_counts()
# Out:
# Theft                                           28274
# Theft: All Other Larceny                        13539
# Theft: BOV                                      10545
# Burglary /                                       5670
# Burglary                                         4927
# Theft: Shoplifting                               4284
# Auto Theft                                       4206
# Agg Assault                                      1915
# Aggravated Assault                               1888
# Robbery                                          1809
# Rape                                             1042
# Theft: Pocket Picking                             448
# Theft: Auto Parts                                 231
# Theft: from Building                              221
# Theft: Coin Op Machine                            153
# Homicide: Murder & Nonnegligent Manslaughter       32
# Murder                                             23
# Theft: Purse Snatching                              7
# Name: primary_type, dtype: int64

# %%
### Note that 'Burglary / ' are all NAN possible privacy issue

# %%
target_df_s = target_df_p.copy().dropna()

# %%
#Set up train test split with One HOt encoding
one_hot4 = OneHotEncoder()
y4 = target_df_s.severe

X4 = one_hot4.fit_transform(target_df_s.copy().drop(['severe', 'primary_type'],axis = 1))
X4_train, X4_test, y4_train, y4_test = train_test_split(X4, y4, 
                                                    test_size=.2)

# %%
# Train and fit model                                                   
rf4 = RandomForestClassifier(random_state=0,n_jobs=-1)

rf4.fit(X4_train, y4_train)
                                     
# Test Prediction
pred = rf4.predict(X4_test)
print('Accuracy score: {:.3}'.format(rf4.score(X4_test, y4_test)))
# Out:
# Accuracy score: 0.759

# %%
feature_df4 = target_df_s.copy().drop(['severe', 'primary_type'], axis = 1)
one_hot_columns4 = one_hot4.get_feature_names(feature_df4.columns)
# Plot the feature importance
feat_scores4 = pd.Series(rf4.feature_importances_, index = one_hot_columns4 )
feat_scores4 = feat_scores4.sort_values()
ax = feat_scores4[-15:].plot(kind='barh', 
                      figsize=(10,8),
                      color='b')
ax.set_title('Average Gini Importance')
ax.set_xlabel('Average contribution to information gain');

# %%
fig,ax = plt.subplots()
ax = feat_scores4[-30:-15].plot(kind='barh', 
                      figsize=(10,8),
                      color='b')
ax.set_title('Average Gini Importance')
ax.set_xlabel('Average contribution to information gain');

# %%
### NOTE when we removed NaN's the data was completely temporal

# %%
import seaborn as sn
true = target_df_s['severe']
predicted = rf4.predict(X4)
data = confusion_matrix(true, predicted)
df_cm = pd.DataFrame(data, columns = np.unique(true), index = np.unique(true))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 16})
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
# Out:
# 14431
